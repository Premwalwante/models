# %%
from transformers import pipeline
generator = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0

# %%
generator =(' i love AI ')

# %%
gpt = pipeline("text-generation", model='gpt2')
# Out:
# Device set to use cuda:0

# %%
gpt('Once upon a time', max_length = 50)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Once upon a time, they would have been a very different band. Now, they are a bigger band.\n\n"So many people were going to be like: \'I\'ve never heard of this band!\' and then I\'d be like: \'Oh, you\'re fucking crazy.\' You\'d be like: \'Why are you so mad?\' and then I\'d be like: \'Oh, you\'re the one who made this band!\' and then someone would go and say, \'Oh, yeah, here\'s what I thought of it.\' That\'s when it was really cool that they got back together—I was like: \'Oh yeah, here\'s what I thought of this band.\' But then I got back to the band and, well, it\'s been a while since I\'ve heard of that."\n\nRicardo\'s full interview with Pitchfork is below.\n\nWatch Rico\'s full interview with Pitchfork below:'}]

# %%
gpt("the day the sun didint rise", max_length = 50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'the day the sun didint rise from the sea. And the old man who had been the chief of the gods, who had been the only man at all the ages of their history, did not come out of the city of Aroos, but came out of a man of the desert, and went along the shore of the sea. And, behold, the day the sun didint rise, the sun went up, and the earth was filled with dust. And the old man who had been the chief of the gods did not come out of the city of Aroos, but came out of the man of the desert. And the old man who had been the chief of the gods did not come out of the city of Aroos, but came out of the man of the desert, and went along the shore of the sea. But, behold, the day the sun didint rise, the sun went up, and the earth was filled with dust. And the old man who had been the chief of the gods did not come out of the city of Aroos, but came out of the man of the desert, and went along the shore of the sea. And the old man who had been the chief of the gods did not come out of the city of Aroos,'}]

# %%
gpt("hi everyone")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'hi everyone.\n\nThe team\'s success will be helped by the fact that they are not afraid to give their all to it.\n\n"It\'s been difficult for me to come into the stadium," said Graziano, "but I\'ve had a lot of support. I feel like we\'re going to be able to do it all over again. We\'re going to have to keep our heads down."\n\nThe team have made it clear to fans that their ambition is to win every game in the first round.\n\n"We\'re trying to win every game we can in the first round," said Graziano, "so we\'re not going to sit around and wait for our opponents to come out and take the win.\n\n"We\'re going to go out there and play and win every game we can. We\'ve got to show we\'re ready to push and do whatever it takes to win every game."'}]

# %%
gpt("I think i am a cyber scurity expert")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "I think i am a cyber scurity expert. But no, I don't want anyone to feel offended or ashamed.\n\nI did not write this because I am not an expert, but because I am a cyber scurity expert. I think i am a cyber scurity expert. But no, I don't want anyone to feel offended or ashamed. I'm not going to be a scurity expert; my goal is to learn from it.\n\nI did not write this because I am not an expert, but because I am a cyber scurity expert. I think i am a cyber scurity expert. But no, I don't want anyone to feel offended or ashamed. I'm not going to be a cyber scurity expert; my goal is to learn from it. I'm not going to be a scurity expert; my goal is to be a hacker. I'm not an expert. I do not care about cyber security\n\nI do not care about cyber security I do not care about cyber security I don't care about cyber security I don't care about cyber security I don't care about cyber security I don't care about cyber security I don't care about cyber security I don't care about cyber security I don't care about cyber security I do not care about cyber security I do"}]

# %%
generator=("i want to kill")

# %%
asr = pipeline("automatic-speech-recognition", model="openai/whisper-large-v3")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
gpt("hi , what can u do for me")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'hi , what can u do for me?\n\nAnonymity and anonymity are at risk when making these decisions – and they are certainly not the only ones.\n\nFor many years, the EU has been trying to take an active role in combating terrorism. The EU is an institution that protects its citizens and the security of its citizens.\n\nBut in recent years, the EU has become increasingly concerned about its own privacy.\n\nIn January 2015, the Home Office announced a new bill that would introduce the Data Retention and Investigatory Powers Act (DRA).\n\nThe legislation, called the "Freedom of Information Act", aims to give the EU the ability to collect and store personal information about internet users.\n\nIt will give the EU the ability to "collect the personal information of individuals and organisations who use the internet, including those who are not personally identifiable, such as those who are not a member of the EU".\n\nUnder the law, any person who is not a member of the EU will be able to obtain a "personal information" about them.\n\nThe law also provides for the EU to monitor organisations, companies and individuals in relation to their use of the internet and to assist them in the investigation of those who use the internet.\n\nThe government\'s proposals would'}]

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# Your max_length is set to 50, but your input_length is only 9. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
# [{'summary_text': 'Long article or paragraph goes here. Long article or paragraphs goes here... Long article/paragraph goes here ... long article/paraphrase.'}]

# %%
print(summarizer("Text generation models have revolutionized the field of natural language processing by enabling machines to produce coherent, contextually relevant, and human-like text. These models, built using advanced deep learning architectures like transformers, are trained on vast datasets containing books, websites, conversations, and code. They are capable of completing prompts, answering questions, writing essays, summarizing documents, generating programming code, and even mimicking specific writing styles or tones. Over the years, models such as OpenAI’s GPT series, Meta’s LLaMA, Mistral’s Mixtral, and Google’s Gemma have pushed the boundaries of what’s possible, making them powerful tools for researchers, developers, and content creators alike. With multilingual capabilities and instruction tuning, newer models not only understand and generate text in various languages but can also follow complex instructions and engage in meaningful dialogue. As these models grow in size and sophistication, they continue to raise important questions about responsible AI use, data privacy, and the future of work. Still, their contributions to education, accessibility, communication, and creativity are undeniable, marking a transformative era in human-computer interaction.", max_length=50, min_length=20))
# Out:
# [{'summary_text': 'Text generation models have revolutionized the field of natural language processing. They enable machines to produce coherent, contextually relevant, and human-like text. With multilingual capabilities and instruction tuning, newer models not only understand and generate text in'}]

# %%
translator = pipeline("translation_en_to_fr", model="Helsinki-NLP/opus-mt-en-hi")
print(translator(" Are you married ?"))
# Out:
# Device set to use cuda:0
# [{'translation_text': 'क्या आप शादीशुदा हैं?'}]

# %%
classifier = pipeline("zero-shot-classification")
     print(classifier( "This is a powerful laptop for gaming.",
                  candidate_labels=["technology", "sports", "food"] ))
# Out:
#   File "/tmp/ipython-input-42-2401619156.py", line 2
#     print(classifier( "This is a powerful laptop for gaming.",
#     ^
# IndentationError: unexpected indent

# %%
classifier = pipeline("zero-shot-classification")
print(classifier(
    "This is a powerful laptop for gaming.",
                  candidate_labels=["technology", "sports", "food"] ))
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
classifier = pipeline("zero-shot-classification")
print(classifier(
    "I am diploma student",
                  candidate_labels=["technology", "sports", "food"] ))
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0
# {'sequence': 'I am diploma student', 'labels': ['technology', 'sports', 'food'], 'scores': [0.5153681039810181, 0.28190043568611145, 0.20273151993751526]}

# %%
fill_mask = pipeline("fill-mask", model="bert-base-uncased")
print(fill_mask("The capital of France is [MASK]."))
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'score': 0.4167884886264801, 'token': 3000, 'token_str': 'paris', 'sequence': 'the capital of france is paris.'}, {'score': 0.07141659408807755, 'token': 22479, 'token_str': 'lille', 'sequence': 'the capital of france is lille.'}, {'score': 0.0633925125002861, 'token': 10241, 'token_str': 'lyon', 'sequence': 'the capital of france is lyon.'}, {'score': 0.044447433203458786, 'token': 16766, 'token_str': 'marseille', 'sequence': 'the capital of france is marseille.'}, {'score': 0.03029710426926613, 'token': 7562, 'token_str': 'tours', 'sequence': 'the capital of france is tours.'}]

# %%
from transformers import pipeline
from PIL import Image
image = Image.open("/content/cat.jpg")
classifier = pipeline("image-classification", model="google/vit-base-patch16-224")
print(classifier(image))
# Out:
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cuda:0
# [{'label': 'Egyptian cat', 'score': 0.7378576397895813}, {'label': 'tabby, tabby cat', 'score': 0.14274410903453827}, {'label': 'tiger cat', 'score': 0.08101203292608261}, {'label': 'lynx, catamount', 'score': 0.005879415199160576}, {'label': 'Siamese cat, Siamese', 'score': 0.003920047543942928}]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello students!"

# Tokenize
tokens = tokenizer.tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['hello', 'students', '!']

# %%
ids = tokenizer.convert_tokens_to_ids(tokens)
print("Token IDs:", ids)

# Encode input for model
encoded = tokenizer("my name is prem", return_tensors="pt")
print(encoded)
# Out:
# Token IDs: [7592, 2493, 999]
# {'input_ids': tensor([[  101,  2026,  2171,  2003, 26563,   102]]), 'token_type_ids': tensor([[0, 0, 0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# [CLS] my name is prem [SEP]

# %%
# Decode back to text
print(tokenizer.decode(encoded['input_ids'][0]))
# Out:
# [CLS] my name is prem [SEP]

# %%
models = ["bert-base-uncased", "roberta-base", "gpt2"]
text = "Transformers are amazing!"

for model_name in models:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tokens = tokenizer.tokenize(text)
    print(f"\n{model_name} Tokens: {tokens}")
# Out:
# bert-base-uncased Tokens: ['transformers', 'are', 'amazing', '!']
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# roberta-base Tokens: ['Transform', 'ers', 'Ġare', 'Ġamazing', '!']
#
# gpt2 Tokens: ['Transform', 'ers', 'Ġare', 'Ġamazing', '!']

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

text = "I love this course!"

inputs = tokenizer(text, return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits
prediction = torch.argmax(logits)

labels = ["Negative", "Positive"]
print("Sentiment:", labels[prediction])
# Out:
# Sentiment: Positive
